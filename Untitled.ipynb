# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("info.csv")

# %%
df
# Out:
#             State  State                Region  Population  \
# 0          Alabama    AL    East South Central   4,874,747
# 1         Arkansas    AR    West South Central   3,004,279
# 2           Alaska    AK               Pacific     739,795
# 3        Louisiana    LA    West South Central   4,684,333
# 4      Mississippi    MS    East South Central   2,984,100
# 5         Oklahoma    OK    West South Central   3,930,864
# 6         Missouri    MO    West North Central   6,113,532
# 7          Montana    MT              Mountain   1,050,493
# 8       New Mexico    NM              Mountain   2,088,070
# 9   South Carolina    SC        South Atlantic   5,024,369
# 10        Kentucky    KY    East South Central   4,454,189
# 11   West Virginia    WV        South Atlantic   1,815,857
# 12         Wyoming    WY              Mountain     579,315
# 13       Tennessee    TN    East South Central   6,715,984
# 14          Nevada    NV              Mountain   2,998,039
# ...

# %%
df.describe()
# Out:
#        % of Pop. below Poverty  \
# count                51.000000
# mean                 14.933333
# std                   3.108419
# min                   9.200000
# 25%                  12.150000
# 50%                  15.200000
# 75%                  17.550000
# max                  21.900000
#
#        Income distribution inequality (Gini Coefficient)  \
# count                                          51.000000
# mean                                            0.466275
# std                                             0.021630
# min                                             0.420000
# 25%                                             0.450000
# 50%                                             0.470000
# 75%                                             0.480000
# max                                             0.530000
#
#        % Gun Ownership- State  % Bachelors Degree  Firearm Deaths per 100,000  \
# ...
